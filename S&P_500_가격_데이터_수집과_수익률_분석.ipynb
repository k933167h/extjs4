# %% [markdown]
# <a href="https://colab.research.google.com/github/k933167h/extjs4/blob/master/S%26P_500_%EA%B0%80%EA%B2%A9_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%88%98%EC%A7%91%EA%B3%BC_%EC%88%98%EC%9D%B5%EB%A5%A0_%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## FinanceDataReader 설치 (for 구글 Colab)

# !pip install -q finance-datareader
# %matplotlib inline
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (14,8)
plt.rcParams['font.size'] = 16
plt.rcParams['lines.linewidth'] = 2
plt.rcParams["axes.grid"] = True
plt.rcParams['axes.axisbelow'] = True
# S&P500 종목 리스트
import FinanceDataReader as fdr

sp500 = fdr.StockListing('S&P500')
sp500.head(10)

# S&P500 종목은 실제 505개
len(sp500)


# 데이터 수집과 저장
# 가격 데이터 가져오기 예시
import FinanceDataReader as fdr

aapl = fdr.DataReader('AAPL', '2010-01-01', '2019-12-31')
aapl.head(10)

aapl.tail(10)

# CSV 파일로 저장하기
# 디렉토리가 없으면 생성
import os
folder = "sp500_price"
if not os.path.isdir(folder):
    os.mkdir(folder)

import csv
import pandas as pd

for ix, row in sp500.iterrows():
    sym, name = row['Symbol'], row['Name']
    csv_fn = os.path.join(folder, f'{sym}.csv')
    if os.path.exists(csv_fn):
        print('skip', csv_fn)
        continue

    try:
      print(csv_fn, end=' ')
      df = fdr.DataReader(sym, '2019-01-01', '2019-12-31')
      df['Symbol'] = sym
      print(len(df), 'rows')
      df.to_csv(csv_fn, quoting=csv.QUOTE_MINIMAL)
    except ValueError as e:
      print(e)
    except IndexError as e:
      print(e)
# 읽어서 확인
sym = 'MMM'
csv_fn = os.path.join(folder, f'{sym}.csv')
mmm = pd.read_csv(csv_fn, parse_dates=True, index_col='Date')
mmm.head()

mmm.tail()

# S&P500 지수
us500 = fdr.DataReader('US500', '2010-01-01', '2019-12-31')
us500.head()

df_plot = pd.DataFrame()

df_plot['S&P500'] = us500['Close']
df_plot['AAPL'] = aapl['Close']

df_plot = df_plot / df_plot.iloc[0] - 1.0
df_plot.plot()

changes = us500['Close'].pct_change()

(changes + 1).product() - 1

changes = aapl['Close'].pct_change()

(changes + 1).product() - 1

# S&P500 전체 종목의 가격
df_price = pd.DataFrame() 

for ix, row in sp500.iterrows():
  try:
    sym, name = row['Symbol'], row['Name']
    csv_fn = os.path.join(folder, f'{sym}.csv')
    print(csv_fn)
    df = pd.read_csv(csv_fn, parse_dates=True, index_col='Date')
    df_price[sym] = df['Close']
  except FileNotFoundError as e:
    print(e)
  except ValueError as e:
    print(e)    
df_price.tail(10)

df_price.columns

len(df_price.columns)

# 2019 수익률 Best, Worst 20
# df.pct_change()
# (df_price['2019'].pct_change() + 1).product() - 1

returns = (df_price['2019'].pct_change() + 1).product() - 1
returns = returns.sort_values(ascending=False)

# Best 20
best20 = returns.head(20)
best20

# Worst 20
worst20 = returns.tail(20)[::-1]
worst20

#2019 수익률 상위 10
# Best 10
best10 = returns.head(10)
best10

df_price.loc['2019', best10.keys()].head(20)

import matplotlib as mpl
import numpy as np

def make_colors(n, colormap=plt.cm.Spectral):
    return colormap(np.linspace(0.1, 1.0, n))
df_plot = pd.DataFrame()

df_plot['S&P500'] = us500.loc['2019', 'Close'] # S&P500 지수
df_plot[best10.keys()] = df_price.loc['2019', best10.keys()] # 10개 종목

df_plot = df_plot / df_plot.iloc[0] - 1
df_plot.plot(color=make_colors(11))

worst10 = returns.tail(10)[::-1]
df_plot = pd.DataFrame()

df_plot['S&P500'] = us500.loc['2019', 'Close'] # S&P500 지수
df_plot[worst10.keys()] = df_price.loc['2019', worst10.keys()] # 10개 종목

df_plot = df_plot / df_plot.iloc[0] - 1
df_plot.plot(color=make_colors(11))

# 수익률
df = pd.DataFrame()

df['S&P500'] = us500.loc['2019', 'Close'] # S&P500 지수
df[best20.keys()] = df_price.loc['2019', best20.keys()]
df.head(20)

# 종목간 상관관계
changes = df.pct_change()
corr = changes.corr()
corr.head(10)

# 상관관계 히트맵

plt.figure(figsize=(16,8))
plt.grid(False)
plt.imshow(corr, cmap='hot', interpolation='none')
plt.colorbar()
plt.xticks(range(len(corr)), corr.columns, rotation=90)
plt.yticks(range(len(corr)), corr.columns)
plt.show()

# 상관계수 순위 만들기 (수익률 상위 20종목)
import pandas as pd

idx, vals = [], []
for ix, i in enumerate(corr.columns.values):
    for j in corr.columns.values[ix + 1:]:
        idx.append((i, j))
        vals.append(corr[i][j])

ser = pd.Series(data=vals, index=idx)
ser_ord = ser.sort_values(ascending=False)
ser_ord[:20]

# 지수와 상관관계
changes = df.pct_change()
corr = changes.corr()
corr['S&P500'].sort_values(ascending=False)[1:]


# 스캐터 차트, 수익과 위험 분석
# 수익 (returns): 수익률 평균 (mean)
# 위험 (risk): 표준편차 (std)
plt.figure(figsize=(16,8))
plt.scatter(changes.mean(), changes.std())
plt.xlabel('returns')
plt.ylabel('risk')
plt.xlim(0.0005, 0.003)
plt.ylim(0.005, 0.030)
for label, x, y in zip(changes.columns, changes.mean(), changes.std()):
    plt.annotate( label, xy=(x, y), xytext=(30, -30),
    textcoords = 'offset points',
    ha = 'right', va = 'bottom',
    bbox = dict(boxstyle = 'round,pad=0.5', fc = 'yellow', alpha = 0.5),
    arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))  

# 전체 종목에서 2019년 수익률 상관관계 상위 종목

df = pd.DataFrame()

df['S&P500'] = us500.loc['2019', 'Close'] # S&P500 지수
df[df_price.columns] = df_price.loc['2019', df_price.columns]

# 종목간 상관관계
changes = df.pct_change()
corr = changes.corr()

idx, vals = [], []
for ix, i in enumerate(corr.columns.values):
    for j in corr.columns.values[ix + 1:]:
        idx.append((i, j))
        vals.append(corr[i][j])

ser = pd.Series(data=vals, index=idx)
ser_ord = ser.sort_values(ascending=False)
ser_ord[:40]

# 상관계수가 높은 페어 종목
df_price[['CMS', 'WEC']].plot()

df_plot = df_price[['CMS', 'WEC']]
df_plot = df_plot / (df_plot.max() - df_plot.min())
df_plot.plot()

df_plot = df_price[['CMS', 'WEC']]
df_plot = df_plot / df_plot.iloc[0]
df_plot.plot()

# 데이터 다운로드 (구글 Colab)
# !zip -r sp500_price.zip sp500_price
# from google.colab import files
# files.download('sp500_price.zip')
# Out:
# skip sp500_price/MMM.csv
# skip sp500_price/AOS.csv
# skip sp500_price/ABT.csv
# skip sp500_price/ABBV.csv
# skip sp500_price/ABMD.csv
# skip sp500_price/ACN.csv
# skip sp500_price/ATVI.csv
# skip sp500_price/ADM.csv
# skip sp500_price/ADBE.csv
# skip sp500_price/ADP.csv
# skip sp500_price/AAP.csv
# skip sp500_price/AES.csv
# skip sp500_price/AFL.csv
# skip sp500_price/A.csv
# skip sp500_price/APD.csv
# skip sp500_price/AKAM.csv
# skip sp500_price/ALK.csv
# skip sp500_price/ALB.csv
# skip sp500_price/ARE.csv
# skip sp500_price/ALGN.csv
# skip sp500_price/ALLE.csv
# skip sp500_price/LNT.csv
# skip sp500_price/ALL.csv
# skip sp500_price/GOOGL.csv
# skip sp500_price/GOOG.csv
# skip sp500_price/MO.csv
# skip sp500_price/AMZN.csv
# skip sp500_price/AMCR.csv
# skip sp500_price/AMD.csv
# skip sp500_price/AEE.csv
# skip sp500_price/AAL.csv
# skip sp500_price/AEP.csv
# skip sp500_price/AXP.csv
# skip sp500_price/AIG.csv
# skip sp500_price/AMT.csv
# skip sp500_price/AWK.csv
# skip sp500_price/AMP.csv
# skip sp500_price/ABC.csv
# skip sp500_price/AME.csv
# skip sp500_price/AMGN.csv
# skip sp500_price/APH.csv
# skip sp500_price/ADI.csv
# skip sp500_price/ANSS.csv
# skip sp500_price/AON.csv
# skip sp500_price/APA.csv
# skip sp500_price/AAPL.csv
# skip sp500_price/AMAT.csv
# skip sp500_price/APTV.csv
# skip sp500_price/ANET.csv
# skip sp500_price/AJG.csv
# skip sp500_price/AIZ.csv
# skip sp500_price/T.csv
# skip sp500_price/ATO.csv
# skip sp500_price/ADSK.csv
# skip sp500_price/AZO.csv
# skip sp500_price/AVB.csv
# skip sp500_price/AVY.csv
# skip sp500_price/BKR.csv
# skip sp500_price/BALL.csv
# skip sp500_price/BAC.csv
# skip sp500_price/BBWI.csv
# skip sp500_price/BAX.csv
# skip sp500_price/BDX.csv
# skip sp500_price/WRB.csv
# skip sp500_price/BRKB.csv
# skip sp500_price/BBY.csv
# skip sp500_price/BIO.csv
# skip sp500_price/TECH.csv
# skip sp500_price/BIIB.csv
# skip sp500_price/BLK.csv
# skip sp500_price/BK.csv
# skip sp500_price/BA.csv
# skip sp500_price/BKNG.csv
# skip sp500_price/BWA.csv
# skip sp500_price/BXP.csv
# skip sp500_price/BSX.csv
# skip sp500_price/BMY.csv
# skip sp500_price/AVGO.csv
# skip sp500_price/BR.csv
# skip sp500_price/BRO.csv
# skip sp500_price/BFB.csv
# skip sp500_price/CHRW.csv
# skip sp500_price/CDNS.csv
# skip sp500_price/CZR.csv
# skip sp500_price/CPT.csv
# skip sp500_price/CPB.csv
# skip sp500_price/COF.csv
# skip sp500_price/CAH.csv
# skip sp500_price/KMX.csv
# skip sp500_price/CCL.csv
# skip sp500_price/CARR.csv
# skip sp500_price/CTLT.csv
# skip sp500_price/CAT.csv
# skip sp500_price/CBOE.csv
# skip sp500_price/CBRE.csv
# skip sp500_price/CDW.csv
# skip sp500_price/CE.csv
# skip sp500_price/CNC.csv
# skip sp500_price/CNP.csv
# skip sp500_price/CDAY.csv
# skip sp500_price/CF.csv
# skip sp500_price/CRL.csv
# skip sp500_price/SCHW.csv
# skip sp500_price/CHTR.csv
# skip sp500_price/CVX.csv
# skip sp500_price/CMG.csv
# skip sp500_price/CB.csv
# skip sp500_price/CHD.csv
# skip sp500_price/CI.csv
# skip sp500_price/CINF.csv
# skip sp500_price/CTAS.csv
# skip sp500_price/CSCO.csv
# skip sp500_price/C.csv
# skip sp500_price/CFG.csv
# skip sp500_price/CLX.csv
# skip sp500_price/CME.csv
# skip sp500_price/CMS.csv
# skip sp500_price/KO.csv
# skip sp500_price/CTSH.csv
# skip sp500_price/CL.csv
# skip sp500_price/CMCSA.csv
# skip sp500_price/CMA.csv
# skip sp500_price/CAG.csv
# skip sp500_price/COP.csv
# skip sp500_price/ED.csv
# skip sp500_price/STZ.csv
# skip sp500_price/CEG.csv
# skip sp500_price/COO.csv
# skip sp500_price/CPRT.csv
# skip sp500_price/GLW.csv
# skip sp500_price/CTVA.csv
# skip sp500_price/CSGP.csv
# skip sp500_price/COST.csv
# skip sp500_price/CTRA.csv
# skip sp500_price/CCI.csv
# skip sp500_price/CSX.csv
# skip sp500_price/CMI.csv
# skip sp500_price/CVS.csv
# skip sp500_price/DHI.csv
# skip sp500_price/DHR.csv
# skip sp500_price/DRI.csv
# skip sp500_price/DVA.csv
# skip sp500_price/DE.csv
# skip sp500_price/DAL.csv
# skip sp500_price/XRAY.csv
# skip sp500_price/DVN.csv
# skip sp500_price/DXCM.csv
# skip sp500_price/FANG.csv
# skip sp500_price/DLR.csv
# skip sp500_price/DFS.csv
# skip sp500_price/DISH.csv
# skip sp500_price/DIS.csv
# skip sp500_price/DG.csv
# skip sp500_price/DLTR.csv
# skip sp500_price/D.csv
# skip sp500_price/DPZ.csv
# skip sp500_price/DOV.csv
# skip sp500_price/DOW.csv
# skip sp500_price/DTE.csv
# skip sp500_price/DUK.csv
# skip sp500_price/DD.csv
# skip sp500_price/DXC.csv
# skip sp500_price/EMN.csv
# skip sp500_price/ETN.csv
# skip sp500_price/EBAY.csv
# skip sp500_price/ECL.csv
# skip sp500_price/EIX.csv
# skip sp500_price/EW.csv
# skip sp500_price/EA.csv
# skip sp500_price/ELV.csv
# skip sp500_price/LLY.csv
# skip sp500_price/EMR.csv
# skip sp500_price/ENPH.csv
# skip sp500_price/ETR.csv
# skip sp500_price/EOG.csv
# skip sp500_price/EPAM.csv
# skip sp500_price/EQT.csv
# skip sp500_price/EFX.csv
# skip sp500_price/EQIX.csv
# skip sp500_price/EQR.csv
# skip sp500_price/ESS.csv
# skip sp500_price/EL.csv
# skip sp500_price/ETSY.csv
# skip sp500_price/RE.csv
# skip sp500_price/EVRG.csv
# skip sp500_price/ES.csv
# skip sp500_price/EXC.csv
# skip sp500_price/EXPE.csv
# skip sp500_price/EXPD.csv
# skip sp500_price/EXR.csv
# skip sp500_price/XOM.csv
# skip sp500_price/FFIV.csv
# skip sp500_price/FDS.csv
# skip sp500_price/FAST.csv
# skip sp500_price/FRT.csv
# skip sp500_price/FDX.csv
# skip sp500_price/FITB.csv
# skip sp500_price/FRC.csv
# skip sp500_price/FE.csv
# skip sp500_price/FIS.csv
# skip sp500_price/FISV.csv
# skip sp500_price/FLT.csv
# skip sp500_price/FMC.csv
# skip sp500_price/F.csv
# skip sp500_price/FTNT.csv
# skip sp500_price/FTV.csv
# skip sp500_price/FBHS.csv
# skip sp500_price/FOXA.csv
# skip sp500_price/FOX.csv
# skip sp500_price/BEN.csv
# skip sp500_price/FCX.csv
# skip sp500_price/GRMN.csv
# skip sp500_price/IT.csv
# skip sp500_price/GNRC.csv
# skip sp500_price/GD.csv
# skip sp500_price/GE.csv
# skip sp500_price/GIS.csv
# skip sp500_price/GM.csv
# skip sp500_price/GPC.csv
# skip sp500_price/GILD.csv
# skip sp500_price/GL.csv
# skip sp500_price/GPN.csv
# skip sp500_price/GS.csv
# skip sp500_price/HAL.csv
# skip sp500_price/HIG.csv
# skip sp500_price/HAS.csv
# skip sp500_price/HCA.csv
# skip sp500_price/PEAK.csv
# skip sp500_price/HSIC.csv
# skip sp500_price/HSY.csv
# skip sp500_price/HES.csv
# skip sp500_price/HPE.csv
# skip sp500_price/HLT.csv
# skip sp500_price/HOLX.csv
# skip sp500_price/HD.csv
# skip sp500_price/HON.csv
# skip sp500_price/HRL.csv
# skip sp500_price/HST.csv
# skip sp500_price/HWM.csv
# skip sp500_price/HPQ.csv
# skip sp500_price/HUM.csv
# skip sp500_price/HBAN.csv
# skip sp500_price/HII.csv
# skip sp500_price/IBM.csv
# skip sp500_price/IEX.csv
# skip sp500_price/IDXX.csv
# skip sp500_price/ITW.csv
# skip sp500_price/ILMN.csv
# skip sp500_price/INCY.csv
# skip sp500_price/IR.csv
# skip sp500_price/INTC.csv
# skip sp500_price/ICE.csv
# skip sp500_price/IP.csv
# skip sp500_price/IPG.csv
# skip sp500_price/IFF.csv
# skip sp500_price/INTU.csv
# skip sp500_price/ISRG.csv
# skip sp500_price/IVZ.csv
# skip sp500_price/INVH.csv
# skip sp500_price/IQV.csv
# skip sp500_price/IRM.csv
# skip sp500_price/JBHT.csv
# skip sp500_price/JKHY.csv
# skip sp500_price/J.csv
# skip sp500_price/JNJ.csv
# skip sp500_price/JCI.csv
# skip sp500_price/JPM.csv
# skip sp500_price/JNPR.csv
# skip sp500_price/K.csv
# skip sp500_price/KDP.csv
# skip sp500_price/KEY.csv
# skip sp500_price/KEYS.csv
# skip sp500_price/KMB.csv
# skip sp500_price/KIM.csv
# skip sp500_price/KMI.csv
# skip sp500_price/KLAC.csv
# skip sp500_price/KHC.csv
# skip sp500_price/KR.csv
# skip sp500_price/LHX.csv
# skip sp500_price/LH.csv
# skip sp500_price/LRCX.csv
# skip sp500_price/LW.csv
# skip sp500_price/LVS.csv
# skip sp500_price/LDOS.csv
# skip sp500_price/LEN.csv
# skip sp500_price/LNC.csv
# skip sp500_price/LIN.csv
# skip sp500_price/LYV.csv
# skip sp500_price/LKQ.csv
# skip sp500_price/LMT.csv
# skip sp500_price/L.csv
# skip sp500_price/LOW.csv
# skip sp500_price/LUMN.csv
# skip sp500_price/LYB.csv
# skip sp500_price/MTB.csv
# skip sp500_price/MRO.csv
# skip sp500_price/MPC.csv
# skip sp500_price/MKTX.csv
# skip sp500_price/MAR.csv
# skip sp500_price/MMC.csv
# skip sp500_price/MLM.csv
# skip sp500_price/MAS.csv
# skip sp500_price/MA.csv
# skip sp500_price/MTCH.csv
# skip sp500_price/MKC.csv
# skip sp500_price/MCD.csv
# skip sp500_price/MCK.csv
# skip sp500_price/MDT.csv
# skip sp500_price/MRK.csv
# skip sp500_price/META.csv
# skip sp500_price/MET.csv
# skip sp500_price/MTD.csv
# skip sp500_price/MGM.csv
# skip sp500_price/MCHP.csv
# skip sp500_price/MU.csv
# skip sp500_price/MSFT.csv
# skip sp500_price/MAA.csv
# skip sp500_price/MRNA.csv
# skip sp500_price/MHK.csv
# skip sp500_price/MOH.csv
# skip sp500_price/TAP.csv
# skip sp500_price/MDLZ.csv
# skip sp500_price/MPWR.csv
# skip sp500_price/MNST.csv
# skip sp500_price/MCO.csv
# skip sp500_price/MS.csv
# skip sp500_price/MOS.csv
# skip sp500_price/MSI.csv
# skip sp500_price/MSCI.csv
# skip sp500_price/NDAQ.csv
# skip sp500_price/NTAP.csv
# skip sp500_price/NFLX.csv
# skip sp500_price/NWL.csv
# skip sp500_price/NEM.csv
# skip sp500_price/NWSA.csv
# skip sp500_price/NWS.csv
# skip sp500_price/NEE.csv
# skip sp500_price/NKE.csv
# skip sp500_price/NI.csv
# skip sp500_price/NDSN.csv
# skip sp500_price/NSC.csv
# skip sp500_price/NTRS.csv
# skip sp500_price/NOC.csv
# skip sp500_price/NLOK.csv
# skip sp500_price/NCLH.csv
# skip sp500_price/NRG.csv
# skip sp500_price/NUE.csv
# skip sp500_price/NVDA.csv
# skip sp500_price/NVR.csv
# skip sp500_price/NXPI.csv
# skip sp500_price/ORLY.csv
# skip sp500_price/OXY.csv
# skip sp500_price/ODFL.csv
# skip sp500_price/OMC.csv
# skip sp500_price/ON.csv
# skip sp500_price/OKE.csv
# skip sp500_price/ORCL.csv
# skip sp500_price/OGN.csv
# skip sp500_price/OTIS.csv
# skip sp500_price/PCAR.csv
# skip sp500_price/PKG.csv
# skip sp500_price/PARA.csv
# skip sp500_price/PH.csv
# skip sp500_price/PAYX.csv
# skip sp500_price/PAYC.csv
# skip sp500_price/PYPL.csv
# skip sp500_price/PNR.csv
# skip sp500_price/PEP.csv
# skip sp500_price/PKI.csv
# skip sp500_price/PFE.csv
# skip sp500_price/PCG.csv
# skip sp500_price/PM.csv
# skip sp500_price/PSX.csv
# skip sp500_price/PNW.csv
# skip sp500_price/PXD.csv
# skip sp500_price/PNC.csv
# skip sp500_price/POOL.csv
# skip sp500_price/PPG.csv
# skip sp500_price/PPL.csv
# skip sp500_price/PFG.csv
# skip sp500_price/PG.csv
# skip sp500_price/PGR.csv
# skip sp500_price/PLD.csv
# skip sp500_price/PRU.csv
# skip sp500_price/PEG.csv
# skip sp500_price/PTC.csv
# skip sp500_price/PSA.csv
# skip sp500_price/PHM.csv
# skip sp500_price/QRVO.csv
# skip sp500_price/PWR.csv
# skip sp500_price/QCOM.csv
# skip sp500_price/DGX.csv
# skip sp500_price/RL.csv
# skip sp500_price/RJF.csv
# skip sp500_price/RTX.csv
# skip sp500_price/O.csv
# skip sp500_price/REG.csv
# skip sp500_price/REGN.csv
# skip sp500_price/RF.csv
# skip sp500_price/RSG.csv
# skip sp500_price/RMD.csv
# skip sp500_price/RHI.csv
# skip sp500_price/ROK.csv
# skip sp500_price/ROL.csv
# skip sp500_price/ROP.csv
# skip sp500_price/ROST.csv
# skip sp500_price/RCL.csv
# skip sp500_price/SPGI.csv
# skip sp500_price/CRM.csv
# skip sp500_price/SBAC.csv
# skip sp500_price/SLB.csv
# skip sp500_price/STX.csv
# skip sp500_price/SEE.csv
# skip sp500_price/SRE.csv
# skip sp500_price/NOW.csv
# skip sp500_price/SHW.csv
# skip sp500_price/SBNY.csv
# skip sp500_price/SPG.csv
# skip sp500_price/SWKS.csv
# skip sp500_price/SJM.csv
# skip sp500_price/SNA.csv
# skip sp500_price/SEDG.csv
# skip sp500_price/SO.csv
# skip sp500_price/LUV.csv
# skip sp500_price/SWK.csv
# skip sp500_price/SBUX.csv
# skip sp500_price/STT.csv
# skip sp500_price/STE.csv
# skip sp500_price/SYK.csv
# skip sp500_price/SIVB.csv
# skip sp500_price/SYF.csv
# skip sp500_price/SNPS.csv
# skip sp500_price/SYY.csv
# skip sp500_price/TMUS.csv
# skip sp500_price/TROW.csv
# skip sp500_price/TTWO.csv
# skip sp500_price/TPR.csv
# skip sp500_price/TRGP.csv
# skip sp500_price/TGT.csv
# skip sp500_price/TEL.csv
# skip sp500_price/TDY.csv
# skip sp500_price/TFX.csv
# skip sp500_price/TER.csv
# skip sp500_price/TSLA.csv
# skip sp500_price/TXN.csv
# skip sp500_price/TXT.csv
# skip sp500_price/TMO.csv
# skip sp500_price/TJX.csv
# skip sp500_price/TSCO.csv
# skip sp500_price/TT.csv
# skip sp500_price/TDG.csv
# skip sp500_price/TRV.csv
# skip sp500_price/TRMB.csv
# skip sp500_price/TFC.csv
# skip sp500_price/TWTR.csv
# skip sp500_price/TYL.csv
# skip sp500_price/TSN.csv
# skip sp500_price/USB.csv
# skip sp500_price/UDR.csv
# skip sp500_price/ULTA.csv
# skip sp500_price/UNP.csv
# skip sp500_price/UAL.csv
# skip sp500_price/UPS.csv
# skip sp500_price/URI.csv
# skip sp500_price/UNH.csv
# skip sp500_price/UHS.csv
# skip sp500_price/VLO.csv
# skip sp500_price/VTR.csv
# skip sp500_price/VRSN.csv
# skip sp500_price/VRSK.csv
# skip sp500_price/VZ.csv
# skip sp500_price/VRTX.csv
# skip sp500_price/VFC.csv
# skip sp500_price/VTRS.csv
# skip sp500_price/VICI.csv
# skip sp500_price/V.csv
# skip sp500_price/VNO.csv
# skip sp500_price/VMC.csv
# skip sp500_price/WAB.csv
# skip sp500_price/WBA.csv
# skip sp500_price/WMT.csv
# skip sp500_price/WBD.csv
# skip sp500_price/WM.csv
# skip sp500_price/WAT.csv
# skip sp500_price/WEC.csv
# skip sp500_price/WFC.csv
# skip sp500_price/WELL.csv
# skip sp500_price/WST.csv
# skip sp500_price/WDC.csv
# skip sp500_price/WRK.csv
# skip sp500_price/WY.csv
# skip sp500_price/WHR.csv
# skip sp500_price/WMB.csv
# skip sp500_price/WTW.csv
# skip sp500_price/GWW.csv
# skip sp500_price/WYNN.csv
# skip sp500_price/XEL.csv
# skip sp500_price/XYL.csv
# skip sp500_price/YUM.csv
# skip sp500_price/ZBRA.csv
# skip sp500_price/ZBH.csv
# skip sp500_price/ZION.csv
# skip sp500_price/ZTS.csv
# sp500_price/MMM.csv
# sp500_price/AOS.csv
# sp500_price/ABT.csv
# sp500_price/ABBV.csv
# sp500_price/ABMD.csv
# sp500_price/ACN.csv
# sp500_price/ATVI.csv
# sp500_price/ADM.csv
# sp500_price/ADBE.csv
# sp500_price/ADP.csv
# sp500_price/AAP.csv
# sp500_price/AES.csv
# sp500_price/AFL.csv
# sp500_price/A.csv
# sp500_price/APD.csv
# sp500_price/AKAM.csv
# sp500_price/ALK.csv
# sp500_price/ALB.csv
# sp500_price/ARE.csv
# sp500_price/ALGN.csv
# sp500_price/ALLE.csv
# sp500_price/LNT.csv
# sp500_price/ALL.csv
# sp500_price/GOOGL.csv
# sp500_price/GOOG.csv
# sp500_price/MO.csv
# sp500_price/AMZN.csv
# sp500_price/AMCR.csv
# sp500_price/AMD.csv
# sp500_price/AEE.csv
# sp500_price/AAL.csv
# sp500_price/AEP.csv
# sp500_price/AXP.csv
# sp500_price/AIG.csv
# sp500_price/AMT.csv
# sp500_price/AWK.csv
# sp500_price/AMP.csv
# sp500_price/ABC.csv
# sp500_price/AME.csv
# sp500_price/AMGN.csv
# sp500_price/APH.csv
# sp500_price/ADI.csv
# sp500_price/ANSS.csv
# sp500_price/AON.csv
# sp500_price/APA.csv
# sp500_price/AAPL.csv
# sp500_price/AMAT.csv
# sp500_price/APTV.csv
# sp500_price/ANET.csv
# sp500_price/AJG.csv
# sp500_price/AIZ.csv
# sp500_price/T.csv
# sp500_price/ATO.csv
# sp500_price/ADSK.csv
# sp500_price/AZO.csv
# sp500_price/AVB.csv
# sp500_price/AVY.csv
# sp500_price/BKR.csv
# sp500_price/BALL.csv
# sp500_price/BAC.csv
# sp500_price/BBWI.csv
# sp500_price/BAX.csv
# sp500_price/BDX.csv
# sp500_price/WRB.csv
# sp500_price/BRKB.csv
# 'Date' is not in list
# sp500_price/BBY.csv
# sp500_price/BIO.csv
# sp500_price/TECH.csv
# sp500_price/BIIB.csv
# sp500_price/BLK.csv
# sp500_price/BK.csv
# sp500_price/BA.csv
# sp500_price/BKNG.csv
# sp500_price/BWA.csv
# sp500_price/BXP.csv
# sp500_price/BSX.csv
# sp500_price/BMY.csv
# sp500_price/AVGO.csv
# sp500_price/BR.csv
# sp500_price/BRO.csv
# sp500_price/BFB.csv
# 'Date' is not in list
# sp500_price/CHRW.csv
# sp500_price/CDNS.csv
# sp500_price/CZR.csv
# sp500_price/CPT.csv
# sp500_price/CPB.csv
# sp500_price/COF.csv
# sp500_price/CAH.csv
# sp500_price/KMX.csv
# sp500_price/CCL.csv
# sp500_price/CARR.csv
# 'Date' is not in list
# sp500_price/CTLT.csv
# sp500_price/CAT.csv
# sp500_price/CBOE.csv
# sp500_price/CBRE.csv
# sp500_price/CDW.csv
# sp500_price/CE.csv
# sp500_price/CNC.csv
# sp500_price/CNP.csv
# sp500_price/CDAY.csv
# sp500_price/CF.csv
# sp500_price/CRL.csv
# sp500_price/SCHW.csv
# sp500_price/CHTR.csv
# sp500_price/CVX.csv
# sp500_price/CMG.csv
# sp500_price/CB.csv
# sp500_price/CHD.csv
# sp500_price/CI.csv
# sp500_price/CINF.csv
# sp500_price/CTAS.csv
# sp500_price/CSCO.csv
# sp500_price/C.csv
# sp500_price/CFG.csv
# sp500_price/CLX.csv
# sp500_price/CME.csv
# sp500_price/CMS.csv
# sp500_price/KO.csv
# sp500_price/CTSH.csv
# sp500_price/CL.csv
# sp500_price/CMCSA.csv
# sp500_price/CMA.csv
# sp500_price/CAG.csv
# sp500_price/COP.csv
# sp500_price/ED.csv
# sp500_price/STZ.csv
# sp500_price/CEG.csv
# 'Date' is not in list
# sp500_price/COO.csv
# sp500_price/CPRT.csv
# sp500_price/GLW.csv
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:95: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
# sp500_price/CTVA.csv
# sp500_price/CSGP.csv
# sp500_price/COST.csv
# sp500_price/CTRA.csv
# sp500_price/CCI.csv
# sp500_price/CSX.csv
# sp500_price/CMI.csv
# sp500_price/CVS.csv
# sp500_price/DHI.csv
# sp500_price/DHR.csv
# sp500_price/DRI.csv
# sp500_price/DVA.csv
# sp500_price/DE.csv
# sp500_price/DAL.csv
# sp500_price/XRAY.csv
# sp500_price/DVN.csv
# sp500_price/DXCM.csv
# sp500_price/FANG.csv
# sp500_price/DLR.csv
# sp500_price/DFS.csv
# sp500_price/DISH.csv
# sp500_price/DIS.csv
# sp500_price/DG.csv
# sp500_price/DLTR.csv
# sp500_price/D.csv
# sp500_price/DPZ.csv
# sp500_price/DOV.csv
# sp500_price/DOW.csv
# sp500_price/DTE.csv
# sp500_price/DUK.csv
# sp500_price/DD.csv
# sp500_price/DXC.csv
# sp500_price/EMN.csv
# sp500_price/ETN.csv
# sp500_price/EBAY.csv
# sp500_price/ECL.csv
# sp500_price/EIX.csv
# sp500_price/EW.csv
# sp500_price/EA.csv
# sp500_price/ELV.csv
# sp500_price/LLY.csv
# sp500_price/EMR.csv
# sp500_price/ENPH.csv
# sp500_price/ETR.csv
# sp500_price/EOG.csv
# sp500_price/EPAM.csv
# sp500_price/EQT.csv
# sp500_price/EFX.csv
# sp500_price/EQIX.csv
# sp500_price/EQR.csv
# sp500_price/ESS.csv
# sp500_price/EL.csv
# sp500_price/ETSY.csv
# sp500_price/RE.csv
# sp500_price/EVRG.csv
# sp500_price/ES.csv
# sp500_price/EXC.csv
# sp500_price/EXPE.csv
# sp500_price/EXPD.csv
# sp500_price/EXR.csv
# sp500_price/XOM.csv
# sp500_price/FFIV.csv
# sp500_price/FDS.csv
# sp500_price/FAST.csv
# sp500_price/FRT.csv
# sp500_price/FDX.csv
# sp500_price/FITB.csv
# sp500_price/FRC.csv
# sp500_price/FE.csv
# sp500_price/FIS.csv
# sp500_price/FISV.csv
# sp500_price/FLT.csv
# sp500_price/FMC.csv
# sp500_price/F.csv
# sp500_price/FTNT.csv
# sp500_price/FTV.csv
# sp500_price/FBHS.csv
# sp500_price/FOXA.csv
# sp500_price/FOX.csv
# sp500_price/BEN.csv
# sp500_price/FCX.csv
# sp500_price/GRMN.csv
# sp500_price/IT.csv
# sp500_price/GNRC.csv
# sp500_price/GD.csv
# sp500_price/GE.csv
# sp500_price/GIS.csv
# sp500_price/GM.csv
# sp500_price/GPC.csv
# sp500_price/GILD.csv
# sp500_price/GL.csv
# sp500_price/GPN.csv
# sp500_price/GS.csv
# sp500_price/HAL.csv
# sp500_price/HIG.csv
# sp500_price/HAS.csv
# sp500_price/HCA.csv
# sp500_price/PEAK.csv
# sp500_price/HSIC.csv
# sp500_price/HSY.csv
# sp500_price/HES.csv
# sp500_price/HPE.csv
# sp500_price/HLT.csv
# sp500_price/HOLX.csv
# sp500_price/HD.csv
# sp500_price/HON.csv
# sp500_price/HRL.csv
# sp500_price/HST.csv
# sp500_price/HWM.csv
# sp500_price/HPQ.csv
# sp500_price/HUM.csv
# sp500_price/HBAN.csv
# sp500_price/HII.csv
# sp500_price/IBM.csv
# sp500_price/IEX.csv
# sp500_price/IDXX.csv
# sp500_price/ITW.csv
# sp500_price/ILMN.csv
# sp500_price/INCY.csv
# sp500_price/IR.csv
# sp500_price/INTC.csv
# sp500_price/ICE.csv
# sp500_price/IP.csv
# sp500_price/IPG.csv
# sp500_price/IFF.csv
# sp500_price/INTU.csv
# sp500_price/ISRG.csv
# sp500_price/IVZ.csv
# sp500_price/INVH.csv
# sp500_price/IQV.csv
# sp500_price/IRM.csv
# sp500_price/JBHT.csv
# sp500_price/JKHY.csv
# sp500_price/J.csv
# sp500_price/JNJ.csv
# sp500_price/JCI.csv
# sp500_price/JPM.csv
# sp500_price/JNPR.csv
# sp500_price/K.csv
# sp500_price/KDP.csv
# sp500_price/KEY.csv
# sp500_price/KEYS.csv
# sp500_price/KMB.csv
# sp500_price/KIM.csv
# sp500_price/KMI.csv
# sp500_price/KLAC.csv
# sp500_price/KHC.csv
# sp500_price/KR.csv
# sp500_price/LHX.csv
# sp500_price/LH.csv
# sp500_price/LRCX.csv
# sp500_price/LW.csv
# sp500_price/LVS.csv
# sp500_price/LDOS.csv
# sp500_price/LEN.csv
# sp500_price/LNC.csv
# sp500_price/LIN.csv
# sp500_price/LYV.csv
# sp500_price/LKQ.csv
# sp500_price/LMT.csv
# sp500_price/L.csv
# sp500_price/LOW.csv
# sp500_price/LUMN.csv
# sp500_price/LYB.csv
# sp500_price/MTB.csv
# sp500_price/MRO.csv
# sp500_price/MPC.csv
# sp500_price/MKTX.csv
# sp500_price/MAR.csv
# sp500_price/MMC.csv
# sp500_price/MLM.csv
# sp500_price/MAS.csv
# sp500_price/MA.csv
# sp500_price/MTCH.csv
# sp500_price/MKC.csv
# sp500_price/MCD.csv
# sp500_price/MCK.csv
# sp500_price/MDT.csv
# sp500_price/MRK.csv
# sp500_price/META.csv
# sp500_price/MET.csv
# sp500_price/MTD.csv
# sp500_price/MGM.csv
# sp500_price/MCHP.csv
# sp500_price/MU.csv
# sp500_price/MSFT.csv
# sp500_price/MAA.csv
# sp500_price/MRNA.csv
# sp500_price/MHK.csv
# sp500_price/MOH.csv
# sp500_price/TAP.csv
# sp500_price/MDLZ.csv
# sp500_price/MPWR.csv
# sp500_price/MNST.csv
# sp500_price/MCO.csv
# sp500_price/MS.csv
# sp500_price/MOS.csv
# sp500_price/MSI.csv
# sp500_price/MSCI.csv
# sp500_price/NDAQ.csv
# sp500_price/NTAP.csv
# sp500_price/NFLX.csv
# sp500_price/NWL.csv
# sp500_price/NEM.csv
# sp500_price/NWSA.csv
# sp500_price/NWS.csv
# sp500_price/NEE.csv
# sp500_price/NKE.csv
# sp500_price/NI.csv
# sp500_price/NDSN.csv
# sp500_price/NSC.csv
# sp500_price/NTRS.csv
# sp500_price/NOC.csv
# sp500_price/NLOK.csv
# sp500_price/NCLH.csv
# sp500_price/NRG.csv
# sp500_price/NUE.csv
# sp500_price/NVDA.csv
# sp500_price/NVR.csv
# sp500_price/NXPI.csv
# sp500_price/ORLY.csv
# sp500_price/OXY.csv
# sp500_price/ODFL.csv
# sp500_price/OMC.csv
# sp500_price/ON.csv
# sp500_price/OKE.csv
# sp500_price/ORCL.csv
# sp500_price/OGN.csv
# 'Date' is not in list
# sp500_price/OTIS.csv
# 'Date' is not in list
# sp500_price/PCAR.csv
# sp500_price/PKG.csv
# sp500_price/PARA.csv
# sp500_price/PH.csv
# sp500_price/PAYX.csv
# sp500_price/PAYC.csv
# sp500_price/PYPL.csv
# sp500_price/PNR.csv
# sp500_price/PEP.csv
# sp500_price/PKI.csv
# sp500_price/PFE.csv
# sp500_price/PCG.csv
# sp500_price/PM.csv
# sp500_price/PSX.csv
# sp500_price/PNW.csv
# sp500_price/PXD.csv
# sp500_price/PNC.csv
# sp500_price/POOL.csv
# sp500_price/PPG.csv
# sp500_price/PPL.csv
# sp500_price/PFG.csv
# sp500_price/PG.csv
# sp500_price/PGR.csv
# sp500_price/PLD.csv
# sp500_price/PRU.csv
# sp500_price/PEG.csv
# sp500_price/PTC.csv
# sp500_price/PSA.csv
# sp500_price/PHM.csv
# sp500_price/QRVO.csv
# sp500_price/PWR.csv
# sp500_price/QCOM.csv
# sp500_price/DGX.csv
# sp500_price/RL.csv
# sp500_price/RJF.csv
# sp500_price/RTX.csv
# sp500_price/O.csv
# sp500_price/REG.csv
# sp500_price/REGN.csv
# sp500_price/RF.csv
# sp500_price/RSG.csv
# sp500_price/RMD.csv
# sp500_price/RHI.csv
# sp500_price/ROK.csv
# sp500_price/ROL.csv
# sp500_price/ROP.csv
# sp500_price/ROST.csv
# sp500_price/RCL.csv
# sp500_price/SPGI.csv
# sp500_price/CRM.csv
# sp500_price/SBAC.csv
# sp500_price/SLB.csv
# sp500_price/STX.csv
# sp500_price/SEE.csv
# sp500_price/SRE.csv
# sp500_price/NOW.csv
# sp500_price/SHW.csv
# sp500_price/SBNY.csv
# sp500_price/SPG.csv
# sp500_price/SWKS.csv
# sp500_price/SJM.csv
# sp500_price/SNA.csv
# sp500_price/SEDG.csv
# sp500_price/SO.csv
# sp500_price/LUV.csv
# sp500_price/SWK.csv
# sp500_price/SBUX.csv
# sp500_price/STT.csv
# sp500_price/STE.csv
# sp500_price/SYK.csv
# sp500_price/SIVB.csv
# sp500_price/SYF.csv
# sp500_price/SNPS.csv
# sp500_price/SYY.csv
# sp500_price/TMUS.csv
# sp500_price/TROW.csv
# sp500_price/TTWO.csv
# sp500_price/TPR.csv
# sp500_price/TRGP.csv
# sp500_price/TGT.csv
# sp500_price/TEL.csv
# sp500_price/TDY.csv
# sp500_price/TFX.csv
# sp500_price/TER.csv
# sp500_price/TSLA.csv
# sp500_price/TXN.csv
# sp500_price/TXT.csv
# sp500_price/TMO.csv
# sp500_price/TJX.csv
# sp500_price/TSCO.csv
# sp500_price/TT.csv
# sp500_price/TDG.csv
# sp500_price/TRV.csv
# sp500_price/TRMB.csv
# sp500_price/TFC.csv
# sp500_price/TWTR.csv
# sp500_price/TYL.csv
# sp500_price/TSN.csv
# sp500_price/USB.csv
# sp500_price/UDR.csv
# sp500_price/ULTA.csv
# sp500_price/UNP.csv
# sp500_price/UAL.csv
# sp500_price/UPS.csv
# sp500_price/URI.csv
# sp500_price/UNH.csv
# sp500_price/UHS.csv
# sp500_price/VLO.csv
# sp500_price/VTR.csv
# sp500_price/VRSN.csv
# sp500_price/VRSK.csv
# sp500_price/VZ.csv
# sp500_price/VRTX.csv
# sp500_price/VFC.csv
# sp500_price/VTRS.csv
# sp500_price/VICI.csv
# sp500_price/V.csv
# sp500_price/VNO.csv
# sp500_price/VMC.csv
# sp500_price/WAB.csv
# sp500_price/WBA.csv
# sp500_price/WMT.csv
# sp500_price/WBD.csv
# sp500_price/WM.csv
# sp500_price/WAT.csv
# sp500_price/WEC.csv
# sp500_price/WFC.csv
# sp500_price/WELL.csv
# sp500_price/WST.csv
# sp500_price/WDC.csv
# sp500_price/WRK.csv
# sp500_price/WY.csv
# sp500_price/WHR.csv
# sp500_price/WMB.csv
# sp500_price/WTW.csv
# sp500_price/GWW.csv
# sp500_price/WYNN.csv
# sp500_price/XEL.csv
# sp500_price/XYL.csv
# sp500_price/YUM.csv
# sp500_price/ZBRA.csv
# sp500_price/ZBH.csv
# sp500_price/ZION.csv
# sp500_price/ZTS.csv
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:110: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self[k1] = value[k2]
